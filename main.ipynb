# %%
import importlib
import dataloader                          # your module name
importlib.reload(dataloader)
from dataloader import get_dvs128_dataloader
traindata,trainloader  = get_dvs128_dataloader(train=True)
testdata,testloader = get_dvs128_dataloader(train=False)
print(len(traindata))
print(len(testdata))
# Out:
# The directory [./Dataset\frames_number_20_split_by_number] already exists.
# The directory [./Dataset\frames_number_20_split_by_number] already exists.
# 1176
# 288

# %%
from utils import visualize
event , label = traindata[0]
visualize(event, label, binned=True)

# %%
import importlib
import utils                          # your module name
importlib.reload(utils)
from utils import inject_label_conv,get_negative_label
output= inject_label_conv(event, label, num_classes=11)
negative= get_negative_label(label, num_classes=11)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3256\3709032180.py in <module>
#       2 import utils                          # your module name
#       3 importlib.reload(utils)
# ----> 4 from utils import inject_label_conv,get_negative_label
#       5 output= inject_label_conv(event, label, num_classes=11)
#       6 negative= get_negative_label(label, num_classes=11)
#
# ImportError: cannot import name 'get_negative_label' from 'utils' (c:\Users\km_ka\Desktop\Neuromorphics\utils.py)
